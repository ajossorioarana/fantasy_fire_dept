# %%
import pandas as pd

# %%
# Import CSV file
df = pd.read_csv('fantasy_fire_department.csv').drop(columns='Unnamed: 0')
df.columns
# Out:
# Index(['City_Name', 'City_State', 'Date', 'Season', 'Climate_Type',
#        'Minimum_Temperature', 'Maximum_Temperature', 'Temperature_AM',
#        'Temperature_PM', 'Wind_Direction_AM', 'Wind_Direction_PM',
#        'Wind_Speed_AM', 'Wind_Speed_PM', 'Max_WindGust_Direction',
#        'Max_WindGust_Speed', 'Significant_Rainfall', 'Rainfall_Amount',
#        'Humidity_AM', 'Humidity_PM', 'Atmospheric_Pressure_AM',
#        'Atmospheric_Pressure_PM', 'CloudCover_Oktas_AM', 'CloudCover_Oktas_PM',
#        'ReductionBurn_Tomorrow'],
#       dtype='object')

# %%
df.head()
# Out:
#   City_Name           City_State        Date  Season Climate_Type  \
# 0  Gaffdenn  Ravenshadow Raiders  1706-07-01  Winter    Temperate
# 1  Gaffdenn  Ravenshadow Raiders  1706-07-02  Winter    Temperate
# 2  Gaffdenn  Ravenshadow Raiders  1706-07-03  Winter    Temperate
# 3  Gaffdenn  Ravenshadow Raiders  1706-07-04  Winter    Temperate
# 4  Gaffdenn  Ravenshadow Raiders  1706-07-06  Winter    Temperate
#
#    Minimum_Temperature  Maximum_Temperature  Temperature_AM  Temperature_PM  \
# 0                  8.8                 15.7            13.5            14.9
# 1                 12.7                 15.8            13.7            15.5
# 2                  6.2                 15.1             9.3            13.9
# 3                  5.3                 15.9            10.2            15.3
# 4                 11.3                 15.7            13.0            14.4
#
#   Wind_Direction_AM  ... Max_WindGust_Speed  Significant_Rainfall  \
# ...
